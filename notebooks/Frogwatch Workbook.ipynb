# %%
from frogwatch.frogwatch import *

from pprint import pprint

# %%
SCHEMA_URL
# Out:
# 'https://frogwatch.fieldscope.org/api/v3/schema/frogwatch/'

# %%
USER_AGENT="Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/110.0"

# %%
session = requests.Session()
session.headers.update({
    "User-Agent": USER_AGENT, 
    "csrftoken": "chQ4Ft5MQDn6bVHCA29SI7MJcTUfh2R9Lsd4Rt2XaVaLvSw4XlWp01CIyS6bPg5m",
    "sessionid": "iby34pnw93l1o62403y39xvno421r6tn",
})

# %%
resp = session.get(SCHEMA_URL)

# %%
dir(resp.request)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_body_position',
#  '_cookies',
#  '_encode_files',
#  '_encode_params',
#  '_get_idna_encoded_host',
#  'body',
#  'copy',
#  'deregister_hook',
#  'headers',
#  'hooks',
#  'method',
#  'path_url',
#  'prepare',
#  'prepare_auth',
#  'prepare_body',
#  'prepare_content_length',
#  'prepare_cookies',
#  'prepare_headers',
#  'prepare_hooks',
#  'prepare_method',
#  'prepare_url',
#  'register_hook',
#  'url']

# %%
resp.request
# Out:
# 200

# %%
pprint(resp.request.headers)
# Out:
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/110.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# _ga=GA1.2.388236779.1675532468; csrftoken=chQ4Ft5MQDn6bVHCA29SI7MJcTUfh2R9Lsd4Rt2XaVaLvSw4XlWp01CIyS6bPg5m; sessionid=iby34pnw93l1o62403y39xvno421r6tn; _gid=GA1.2.1499099129.1678308535

# %% [markdown]
# _ga=GA1.2.388236779.1675532468; csrftoken=chQ4Ft5MQDn6bVHCA29SI7MJcTUfh2R9Lsd4Rt2XaVaLvSw4XlWp01CIyS6bPg5m; sessionid=iby34pnw93l1o62403y39xvno421r6tn; _gid=GA1.2.1499099129.1678308535
