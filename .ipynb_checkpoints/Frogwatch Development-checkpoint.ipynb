# %% [markdown]
# ## Frogwatch Observations

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import sqlite3
db = sqlite3.connect('frogwatch.db')

stations = pd.read_sql('select * from stations', db)
people = pd.read_sql('select * from persons', db)
observations = pd.read_sql('select * from observations', db)

# %%
observations['fs_id'] = observations['fs_id'].apply(pd.to_numeric);
stations['fs_id'] = stations['fs_id'].apply(pd.to_numeric);
people['fs_id'] = people['fs_id'].apply(pd.to_numeric);

# %%
stations
# Out:
#           fs_id                                   name        lon        lat  \
# 0       2208257                    Cohanzick Zoo ponds -75.238670  39.438180
# 1       4904461                       Haddon Lake Park -75.064600  39.877300
# 2       4360220                    Randoplh and Garnet -74.879272  39.041453
# 3       4034591                       Cape May Meadows -74.944447  38.935685
# 4       4034592  Cape May Park South/Fishing Creek WMA -74.932924  39.041249
# ...         ...                                    ...        ...        ...
# 6425  100000537                Cow Creek / W 13th Ave  -97.951370  38.067230
# 6426  100000541                                 Toohey -88.108978  41.859334
# 6427  100000542                  Lowthorpe Meadow pond -72.092100  41.546900
# 6428  100000543                    Walsh and Brooklyn  -85.638154  42.914592
# 6429  100000544              Charlie's Channel Lookout -81.539097  40.956496
#
#                 city      county state   owner_id
# 0          Bridgeton  Cumberland    NJ      24401
# 1     Haddon Heights      Camden    NJ      28607
# 2         Whitesboro    Cape May    NJ      24328
# 3      West Cape May    Cape May    NJ      24328
# 4             Villas    Cape May    NJ      24328
# ...              ...         ...   ...        ...
# 6425      Hutchinson        Reno    KS  100000359
# 6426         Wheaton      Dupage    IL  100000518
# 6427         Norwich  New London    CT  100000519
# 6428    Grand Rapids        Kent    MI  100000387
# 6429    New Franklin      Summit    OH  100000525
#
# [6430 rows x 8 columns]

# %%
observations.head()
# Out:
#       fs_id  station_id  observer_id           start_time  \
# 0  10876470     2208257        24401  2016-03-18 20:26:56
# 1  11190942     2208257        24401  2016-04-21 20:45:27
# 2  11190943     2208257        24401  2016-04-21 20:45:27
# 3  11386189     2208257        24401  2016-05-12 21:04:00
# 4  11386190     2208257        24401  2016-05-12 21:04:00
#
#               end_time           species call_intensity  temperature  \
# 0  2016-03-18 20:29:56  No Species Heard              0         54.0
# 1  2016-04-21 20:48:27     Pickerel Frog              1         62.0
# 2  2016-04-21 20:48:27     Fowler's Toad              3         62.0
# 3  2016-05-12 21:07:00     Spring Peeper              2         62.0
# 4  2016-05-12 21:07:00     Gray Treefrog              3         62.0
#
#   beaufort_wind precip_48h precip above_freezing_48h  \
# 0             1          2      0                  1
# 1             0          1      0                  1
# 2             0          1      0                  1
# 3             0          3      0                  1
# 4             0          3      0                  1
#
#                                                notes
# 0  heard a lone pickerel frog upon arrival, did n...
# 1  Light traffic on road next to ponds, peacocks ...
# 2  Light traffic on road next to ponds, peacocks ...
# 3  Peacocks were insanely loud tonight.  I've see...
# 4  Peacocks were insanely loud tonight.  I've see...

# %% [markdown]
# #### 1. Normalize species names

# %%
sorted(list(observations['species'].unique()))
# Out:
# ['-',
#  'African Clawed Frog',
#  'Amargosa Toad',
#  'American Bullfrog',
#  'American Toad',
#  'American Toad (Subspecies - Dwarf)',
#  'American Toad (Subspecies - Eastern)',
#  'Antillean Coqui',
#  'Arizona Toad',
#  'Arizona treefrog',
#  'Arroyo Toad',
#  'Atlantic Coast Leopard Frog',
#  'Baja California Treefrog',
#  'Barking Frog',
#  'Barking Treefrog',
#  'Bird-voiced Treefrog',
#  "Blanchard's Cricket Frog",
#  'Boreal Chorus Frog',
#  'Boreal/Western Chorus Frog Complex',
#  "Brimley's Chorus Frog",
#  'Cajun Chorus Frog',
#  'Cajun/Boreal Chorus Frog Complex',
#  'California Red-legged Frog',
#  'California Treefrog',
#  'Canadian Toad',
#  'Cane Toad',
#  'Canyon Treefrog',
#  'Carpenter Frog',
#  'Cliff Chirping Frog',
#  'Columbia Spotted Frog',
#  "Cope's Gray Treefrog",
#  'Coqui',
#  "Couch's Spadefoot",
#  'Crawfish Frog',
#  'Crawfish Frog (Subspecies - Northern)',
#  'Crawfish Frog (Subspecies - Southern)',
#  'Cricket Coqui',
#  'Cuban Treefrog',
#  'Eastern Cricket Frog',
#  'Eastern Narrow-mouthed Toad',
#  'Eastern Spadefoot',
#  "Eastern/Hurter's Spadefoot Complex",
#  'Florida Bog Frog',
#  'Florida Gopher Frog',
#  'Foothill Yellow-legged Frog',
#  "Fowler's Toad",
#  "Fowler's/Woodhouse's Toad Complex",
#  'Gopher Frog',
#  'Grass Coqui',
#  'Gray Treefrog',
#  'Great Basin Spadefoot',
#  'Great Plains Toad',
#  'Great Plains/Canadian Toad complex',
#  'Green Frog',
#  'Green Frog (Subspecies - Bronze)',
#  'Green Frog (Subspecies - Northern)',
#  'Green Toad',
#  'Green Toad (Subspecies - Eastern)',
#  'Green Treefrog',
#  'Greenhouse Frog',
#  'Gulf Coast Toad',
#  "Hurter's Spadefoot",
#  'Illinois Chorus Frog',
#  'Little Grass Frog',
#  'Lowland Leopard Frog',
#  'Mexican Spadefoot',
#  'Mink Frog',
#  'Mountain Chorus Frog',
#  'New Jersey Chorus Frog',
#  'No Species Heard',
#  'Northern Cricket Frog (Subspecies - Coastal)',
#  'Northern Cricket Frog Complex',
#  'Northern Leopard Frog',
#  'Northern Pacific Treefrog',
#  'Northern Red-legged Frog',
#  'Oak Toad',
#  'Ornate Chorus Frog',
#  'Pacific Treefrog Complex',
#  'Pickerel Frog',
#  'Pig Frog',
#  'Pine Barrens Treefrog',
#  'Pine Woods Treefrog',
#  'Plains Leopard Frog',
#  'Plains Spadefoot',
#  'Ramsey Canyon Leopard Frog',
#  'Red-legged Frog',
#  'Red-spotted toad',
#  'Rio Grande Chirping Frog',
#  'Rio Grande Leopard Frog',
#  'Sheep Frog',
#  'Sierran Treefrog',
#  'Sonoran Desert Toad',
#  'Southeastern/Western Chorus Frog Complex',
#  'Southern Chorus Frog',
#  'Southern Chorus Frog (Subspecies - Florida)',
#  'Southern Cricket Frog',
#  'Southern Cricket Frog (Subspecies - Coastal Plain)',
#  'Southern Cricket Frog (Subspecies - Florida)',
#  'Southern Leopard Frog',
#  'Southern Toad',
#  'Spotted Chorus Frog',
#  'Spring Peeper',
#  'Spring Peeper (Subspecies - Northern)',
#  'Spring Peeper (Subspecies - Southern)',
#  'Squirrel Treefrog',
#  "Strecker's Chorus frog",
#  'Tarahumara Frog',
#  'Texas Toad',
#  'Unknown Cricket Frog (Acris sp.)',
#  'Unknown Gray Treefrog Species Complex',
#  'Unknown Leopard Frog',
#  'Unknown Toad Species (Anaxyrus sp.)',
#  'Upland Chorus Frog',
#  'Warty Coqui',
#  'Web-footed Coqui',
#  'Western Chorus Frog',
#  'Western Narrow-mouthed Toad',
#  'Western Spadefoot',
#  'Western Toad',
#  'Western Toad (Subspecies - Boreal Toad)',
#  'Whistling Coqui',
#  'Wood Frog',
#  "Woodhouse's Toad",
#  "Woodhouse's Toad (Subspecies - Rocky Mountain Toad)",
#  "Woodhouse's Toad (Subspecies - Southwestern)"]

# %%
import re
observations['species'] = [re.sub(r" \(.*$", "", name) for name in observations['species']]

# %%
observations.groupby('species').size().sort_values(ascending=False).keys()
# Out:
# Index(['Spring Peeper', 'Green Frog', 'No Species Heard', 'Gray Treefrog',
#        'American Bullfrog', 'American Toad', 'Cope's Gray Treefrog',
#        'Wood Frog', 'Pickerel Frog', 'Western Chorus Frog',
#        ...
#        'Coqui', 'Sheep Frog', 'Tarahumara Frog', 'Grass Coqui',
#        'Columbia Spotted Frog', 'Ramsey Canyon Leopard Frog', 'Warty Coqui',
#        'Web-footed Coqui', 'Fowler's/Woodhouse's Toad Complex',
#        'Eastern/Hurter's Spadefoot Complex'],
#       dtype='object', name='species', length=110)

# %% [markdown]
# #### 2. Reassign duplicated SMR stations

# %%
stations[stations['name'].str.contains('SMR')]
# Out:
#           fs_id                                   name        lon        lat  \
# 27    100000202                    SMR-Campbell's Pond -74.305170  40.737490
# 95    100000217            SMR-Crest Trail Vernal Pool -74.290500  40.737440
# 96    100000218                  SMR-Black Willow Pond -74.292310  40.738760
# 97    100000219  SMR-Elmdale Peace Circle Vernal Pools -74.304090  40.746560
# 98    100000220       SMR-Oakdale Overflow Vernal Pool -74.288740  40.763240
# 1290  100000222             SMR-Orange Reservoir North -74.283385  40.768369
# 2314  100000221                  SMR-High Water Bypass -74.292300  40.752550
# 5818  100000215                    SMR-Campbell's Pond -74.303470  40.737706
#
#               city        county state   owner_id
# 27         Milburn         Essex    NJ  100000108
# 95       Maplewood  Essex County    NJ  100000204
# 96       Maplewood  Essex County    NJ  100000204
# 97        Miilburn  Essex County    NJ  100000204
# 98     West Orange  Essex County    NJ  100000204
# 1290   West Orange  Essex County    NJ  100000204
# 2314  South Orange  Essex County    NJ  100000204
# 5818    Millburn\n  Essex County    NJ  100000204

# %%
smr_station_ids = list([int(v) for v in stations[stations['name'].str.contains('SMR')].fs_id])

# %%
len(observations[observations['station_id'].isin(smr_station_ids)])
# Out:
# 26

# %%
stations[stations['name'].str.contains('South Mountain')]
# Out:
#         fs_id                                               name        lon  \
# 9     1480244  South Mountain Reservation Elmdale trail verna... -74.304660
# 20     593550  Crest Drive Deer exclosure, South Mountain Res... -74.292201
# 6293  4975303    South Mountain Reservation-Elmdale/Peace Circle -74.297222
# 6360   605236        Campbell's Pond, South Mountain Reservation -74.303005
#
#             lat         city  county state  owner_id
# 9     40.747420     Millburn   Essex    NJ     20074
# 20    40.738704   Maplewood    Essex    NJ     20074
# 6293  40.746944  Short Hills  Essex     NJ     28679
# 6360  40.738104    Maplewood   Essex    NJ     20074

# %%
observations.loc[observations['station_id'] == 593550, 'station_id'] = 100000218
observations.loc[observations['station_id'] == 1480244, 'station_id'] = 100000219
observations.loc[observations['station_id'] == 605236, 'station_id'] = 100000215
observations.loc[observations['station_id'] == 100000202, 'station_id'] = 100000215
smr_station_ids = [v for v in smr_station_ids if v != 100000202]

# %%
len(observations[observations['station_id'].isin(smr_station_ids)])
# Out:
# 112

# %% [markdown]
# ### Denormalize the obervations

# %%
obs_and_name = pd.merge(
         observations, 
         people[['fs_id', 'name']], 
         how="left", left_on="observer_id", right_on="fs_id", suffixes=[None, "_observer"])

# %%
obs_full = pd.merge(
         obs_and_name, 
         stations[['fs_id', 'name', 'lat', 'lon']], 
         how="left", left_on="station_id", right_on="fs_id", suffixes=["_observer", "_station"])

# %%
obs_full.columns
# Out:
# Index(['fs_id_observer', 'station_id', 'observer_id', 'start_time', 'end_time',
#        'species', 'call_intensity', 'temperature', 'beaufort_wind',
#        'precip_48h', 'precip', 'above_freezing_48h', 'notes', 'fs_id_observer',
#        'name_observer', 'fs_id_station', 'name_station', 'lat', 'lon'],
#       dtype='object')

# %%
observations = obs_full[['station_id', 'observer_id', 'start_time', 
                         'species', 'call_intensity', 'temperature', 'beaufort_wind', 
                         'name_observer', 'name_station', 'lat', 'lon']]

# %%
type(pd.to_datetime(observations['start_time'], utc=True))
# Out:
# pandas.core.series.Series

# %%
pd.Timestamp('2015-04-03 23:45:04').year
observations = observations.assign(
    start_time=pd.to_datetime(observations['start_time'], utc=True))
observations['start_time'].apply(lambda ts: ts.year)
# Out:
# 0         2016
# 1         2016
# 2         2016
# 3         2016
# 4         2016
#           ...
# 121144    2015
# 121145    2015
# 121146    2018
# 121147    2018
# 121148    2018
# Name: start_time, Length: 121149, dtype: int64

# %%
smr_observations = observations[observations['station_id'].isin(smr_station_ids) & 
                                (observations['start_time'].apply(lambda ts: ts.year) >= 2010)
                               ].sort_values(by=['start_time'], ascending=False)
smr_observations.loc[:, ('start_time', 'name_observer', 'species', 'call_intensity', 'temperature', 'beaufort_wind', 'name_station')]
# Out:
#                       start_time      name_observer           species  \
# 120940 2021-04-27 20:39:00+00:00   Cheryl Futterman  No Species Heard
# 120054 2021-04-19 20:38:00+00:00   Catherine Cronin     Spring Peeper
# 120050 2021-04-18 21:12:00+00:00        Tom Pollard     Pickerel Frog
# 120052 2021-04-18 20:38:00+00:00        Tom Pollard  No Species Heard
# 120051 2021-04-18 20:05:00+00:00        Tom Pollard     Gray Treefrog
# ...                          ...                ...               ...
# 200    2014-04-09 21:42:57+00:00  Henry Conrad-Poor         Wood Frog
# 197    2014-04-05 20:57:06+00:00  Henry Conrad-Poor     Spring Peeper
# 198    2014-04-05 20:57:06+00:00  Henry Conrad-Poor         Wood Frog
# 196    2014-03-31 20:27:00+00:00  Henry Conrad-Poor         Wood Frog
# 195    2014-03-31 20:27:00+00:00  Henry Conrad-Poor     Spring Peeper
#
#        call_intensity  temperature beaufort_wind  \
# 120940              0         56.0             0
# 120054              2         61.0             0
# 120050              2         53.0             1
# 120052              0         54.0             1
# 120051              1         54.0             1
# ...               ...          ...           ...
# 200                 0         44.0             2
# 197                 3         44.0             3
# 198                 1         44.0             3
# 196                 2         40.0             0
# 195                 3         40.0             0
#
#                             name_station
# 120940       SMR-Crest Trail Vernal Pool
# 120054             SMR-Black Willow Pond
# 120050               SMR-Campbell's Pond
# 120052  SMR-Oakdale Overflow Vernal Pool
# 120051             SMR-Black Willow Pond
# ...                                  ...
# 200                SMR-Black Willow Pond
# 197                SMR-Black Willow Pond
# 198                SMR-Black Willow Pond
# 196                SMR-Black Willow Pond
# 195                SMR-Black Willow Pond
#
# [112 rows x 7 columns]

# %%
smr_observations.groupby('name_station').size()
# Out:
# name_station
# SMR-Black Willow Pond                    41
# SMR-Campbell's Pond                      48
# SMR-Crest Trail Vernal Pool              11
# SMR-Elmdale Peace Circle Vernal Pools     9
# SMR-Oakdale Overflow Vernal Pool          3
# dtype: int64

# %%
smr_observations.groupby('species')['name_station'].unique()
# Out:
# species
# American Bullfrog              [SMR-Campbell's Pond, SMR-Black Willow Pond]
# Gray Treefrog             [SMR-Black Willow Pond, SMR-Crest Trail Vernal...
# Green Frog                     [SMR-Campbell's Pond, SMR-Black Willow Pond]
# New Jersey Chorus Frog                        [SMR-Crest Trail Vernal Pool]
# No Species Heard          [SMR-Crest Trail Vernal Pool, SMR-Oakdale Over...
# Pickerel Frog                  [SMR-Campbell's Pond, SMR-Black Willow Pond]
# Spring Peeper             [SMR-Black Willow Pond, SMR-Crest Trail Vernal...
# Wood Frog                 [SMR-Black Willow Pond, SMR-Elmdale Peace Circ...
# Name: name_station, dtype: object

# %%
names = list()
species_obs = list()
for species, group in smr_observations.groupby('species'):
    names.append(species)
    species_obs.append({
        "observations": len(group),
        "observers": len(group['name_observer'].unique()),
        "sites": len(group['name_station'].unique()),
    })
pd.DataFrame(species_obs, index=names).sort_values('observations', ascending=False)
# Out:
#                         observations  observers  sites
# Spring Peeper                     40          8      4
# American Bullfrog                 17          2      2
# Green Frog                        15          2      2
# Wood Frog                         14          2      2
# Pickerel Frog                     13          3      2
# No Species Heard                   9          4      4
# Gray Treefrog                      3          2      2
# New Jersey Chorus Frog             1          1      1

# %%
smr_observations.groupby('name_observer').size().sort_values(ascending=False)
# Out:
# name_observer
# Henry Conrad-Poor    72
#                      13
# Tom Pollard          11
# Cheryl Futterman      6
# Maayan Haskell        3
# Amy Hains             2
# Catherine Cronin      2
# Lori LaBorde          2
# Nicky Lazar           1
# dtype: int64

# %%
stations.loc[stations['fs_id'] == 100000219, 'name'].iloc[0]
# Out:
# 'SMR-Elmdale Peace Circle Vernal Pools'

# %%
from collections import defaultdict

station_obs = defaultdict(list)

# create an entry for every station in the given observations
for station_id, obs_ids in smr_observations.groupby(['station_id']).groups.items():
    obs = smr_observations.loc[obs_ids[0]]
    station_obs['station_id'].append(station_id)
    station_obs['name'].append(obs["name_station"])
    station_obs['lat'].append(obs['lat'])
    station_obs['lon'].append(obs["lon"])
    station_obs['observations'].append(len(obs_ids))
    
    species = set([smr_observations.loc[obs_id]['species'] for obs_id in obs_ids])
    station_obs["species"].append(sorted(list([v for v in species if v != "No Species Heard"])))

# Add stations that are defined, but have no observations
for station_id in smr_station_ids:
    if station_id not in station_obs['station_id']:
        station_obs['station_id'].append(station_id)
        station_obs['name'].append(stations.loc[stations['fs_id'] == station_id, "name"].iloc[0])
        station_obs['lat'].append(stations.loc[stations['fs_id'] == station_id, "lat"].iloc[0])
        station_obs['lon'].append(stations.loc[stations['fs_id'] == station_id, "lon"].iloc[0])
        station_obs['observations'].append(0)
        station_obs["species"].append([])

station_obs = pd.DataFrame(station_obs)
station_obs
# Out:
#    station_id                                   name        lat        lon  \
# 0   100000215                    SMR-Campbell's Pond  40.737706 -74.303470
# 1   100000217            SMR-Crest Trail Vernal Pool  40.737440 -74.290500
# 2   100000218                  SMR-Black Willow Pond  40.738760 -74.292310
# 3   100000219  SMR-Elmdale Peace Circle Vernal Pools  40.746560 -74.304090
# 4   100000220       SMR-Oakdale Overflow Vernal Pool  40.763240 -74.288740
# 5   100000222             SMR-Orange Reservoir North  40.768369 -74.283385
# 6   100000221                  SMR-High Water Bypass  40.752550 -74.292300
#
#    observations                                            species
# 0            48  [American Bullfrog, Green Frog, Pickerel Frog,...
# 1            11  [Gray Treefrog, New Jersey Chorus Frog, Spring...
# 2            41  [American Bullfrog, Gray Treefrog, Green Frog,...
# 3             9                         [Spring Peeper, Wood Frog]
# 4             3                                                 []
# 5             0                                                 []
# 6             0                                                 []

# %% [markdown]
# ### Map the observations

# %% [markdown]
# #### Google Maps Plots

# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool, PanTool, WheelZoomTool, ResetTool, TapTool
from bokeh.models import DataTable, DateFormatter, TableColumn
from bokeh.layouts import layout

# %%
from bokeh.models import GMapOptions, Paragraph
from bokeh.plotting import gmap

# %%
import math

map_options = GMapOptions(lat=40.752, lng=-74.294, map_type="terrain", zoom=14)

# Set API key from environment in production:
api_key = "AIzaSyD4IiUSTkgTTe800sjX5LIuVhUsAFsRqG4"

# There may be stations that have no observations, so we define this source independently of the observations
station_source = ColumnDataSource(
    data = dict(
        lat=list(station_obs['lat']),
        lon=list(station_obs['lon']),
        name=list(station_obs['name']),
        count=list(station_obs['observations']),
        species=list(station_obs['species']),
        size=[10 + 7*math.log(v + 1) for v in station_obs['observations']],

    )
)

hover = HoverTool(tooltips=[
    ("site", "@name"),
    ("observations", "@count"),
    ("species", "@species")
])

station_map = gmap(api_key, map_options,
                   tools=[hover, WheelZoomTool(), PanTool(), ResetTool(), TapTool()],
                   title="South Mountain Reservation",
                   width_policy="max")

station_map.circle(x="lon", y="lat", size="size", fill_color="violet", fill_alpha=0.8, source=station_source)
show(station_map)
# Out:
#   <div class="bk-root" id="f2b12c3c-1b59-439b-8dc0-9238198cfc03" data-root-id="1010"></div>

# %%
smr_observations.head()
# Out:
#         station_id  observer_id                start_time           species  \
# 120940   100000217    100000217 2021-04-27 20:39:00+00:00  No Species Heard
# 120054   100000218    100000265 2021-04-19 20:38:00+00:00     Spring Peeper
# 120050   100000215    100000108 2021-04-18 21:12:00+00:00     Pickerel Frog
# 120052   100000220    100000108 2021-04-18 20:38:00+00:00  No Species Heard
# 120051   100000218    100000108 2021-04-18 20:05:00+00:00     Gray Treefrog
#
#        call_intensity  temperature beaufort_wind     name_observer  \
# 120940              0         56.0             0  Cheryl Futterman
# 120054              2         61.0             0  Catherine Cronin
# 120050              2         53.0             1       Tom Pollard
# 120052              0         54.0             1       Tom Pollard
# 120051              1         54.0             1       Tom Pollard
#
#                             name_station        lat       lon
# 120940       SMR-Crest Trail Vernal Pool  40.737440 -74.29050
# 120054             SMR-Black Willow Pond  40.738760 -74.29231
# 120050               SMR-Campbell's Pond  40.737706 -74.30347
# 120052  SMR-Oakdale Overflow Vernal Pool  40.763240 -74.28874
# 120051             SMR-Black Willow Pond  40.738760 -74.29231

# %%
selected_stations = [] # ['SMR-Black Willow Pond']
if selected_stations:
    station_filter = smr_observations['name_station'].isin(selected_stations)
else:
    station_filter = smr_observations['name_station'].notnull()
    
selected_species = ['Wood Frog']
if selected_species:
    species_filter = smr_observations['species'].isin(selected_species)
else:
    species_filter = smr_observations['species'].notnull()
    
# smr_observations[station_filter and species_filter]
smr_observations[species_filter & station_filter]
# Out:
#       station_id  observer_id                start_time    species  \
# 1844   100000218    100000108 2021-03-23 21:37:00+00:00  Wood Frog
# 107    100000219        20074 2019-03-24 23:00:54+00:00  Wood Frog
# 104    100000219        20074 2018-03-29 21:30:31+00:00  Wood Frog
# 227    100000218        20074 2016-03-13 22:00:20+00:00  Wood Frog
# 225    100000218        20074 2016-03-08 20:20:10+00:00  Wood Frog
# 222    100000218        20074 2015-04-11 20:00:51+00:00  Wood Frog
# 102    100000219        20074 2015-04-03 23:45:04+00:00  Wood Frog
# 220    100000218        20074 2015-04-03 20:00:56+00:00  Wood Frog
# 217    100000218        20074 2015-03-27 19:50:07+00:00  Wood Frog
# 219    100000218        20074 2015-03-21 20:00:02+00:00  Wood Frog
# 201    100000218        20074 2014-04-13 20:17:00+00:00  Wood Frog
# 200    100000218        20074 2014-04-09 21:42:57+00:00  Wood Frog
# 198    100000218        20074 2014-04-05 20:57:06+00:00  Wood Frog
# 196    100000218        20074 2014-03-31 20:27:00+00:00  Wood Frog
#
#      call_intensity  temperature beaufort_wind      name_observer  \
# 1844              2         53.0             1        Tom Pollard
# 107               2         50.0             0  Henry Conrad-Poor
# 104               2         49.0             0  Henry Conrad-Poor
# 227               2         50.0             1  Henry Conrad-Poor
# 225               0         47.0             1  Henry Conrad-Poor
# 222               0         47.0             1  Henry Conrad-Poor
# 102               3         61.0             0  Henry Conrad-Poor
# 220               3         61.0             0  Henry Conrad-Poor
# 217               0         45.0             0  Henry Conrad-Poor
# 219               0         40.0             3  Henry Conrad-Poor
# 201               0         71.0             2  Henry Conrad-Poor
# 200               0         44.0             2  Henry Conrad-Poor
# 198               1         44.0             3  Henry Conrad-Poor
# 196               2         40.0             0  Henry Conrad-Poor
#
#                                name_station       lat       lon
# 1844                  SMR-Black Willow Pond  40.73876 -74.29231
# 107   SMR-Elmdale Peace Circle Vernal Pools  40.74656 -74.30409
# 104   SMR-Elmdale Peace Circle Vernal Pools  40.74656 -74.30409
# 227                   SMR-Black Willow Pond  40.73876 -74.29231
# 225                   SMR-Black Willow Pond  40.73876 -74.29231
# 222                   SMR-Black Willow Pond  40.73876 -74.29231
# 102   SMR-Elmdale Peace Circle Vernal Pools  40.74656 -74.30409
# 220                   SMR-Black Willow Pond  40.73876 -74.29231
# 217                   SMR-Black Willow Pond  40.73876 -74.29231
# 219                   SMR-Black Willow Pond  40.73876 -74.29231
# 201                   SMR-Black Willow Pond  40.73876 -74.29231
# 200                   SMR-Black Willow Pond  40.73876 -74.29231
# 198                   SMR-Black Willow Pond  40.73876 -74.29231
# 196                   SMR-Black Willow Pond  40.73876 -74.29231

# %% [markdown]
# ### Unified dashboard
#
# * Define sources for different the dashboard panels from the observations and a set of filters.
# * Allow filters to be defined by interacting with the panels.

# %%
from bokeh.models import Circle
from datetime import datetime

def now():
    return datetime.now().isoformat()

def update_display(doc):

    # Set API key from environment in production:
    api_key = "AIzaSyD4IiUSTkgTTe800sjX5LIuVhUsAFsRqG4"

    all_stations = set(station_obs['name'])
    selected_stations = all_stations
    print(f"{len(selected_stations)} stations")

    all_species = set(smr_observations['species'])
    selected_species = all_species
    print(f"{len(selected_species)} species")
    
    def something_changed(attrname, old, new):
        status.text = attrname + " " + repr(old)

    def obs_selected(attrname, old, new):
        print(f"{now()} - observation selected")
        status.text = f"observations {obs_table.source.selected.indices} selected"
        
    def stations_selected(attrname, old, new):
        print(f"{now()} - station selected")
        nonlocal selected_stations
        selected_stations = list(station_obs['name'][station_source.selected.indices]) or all_stations
        status.text = f"Selected stations {', '.join(selected_stations)}"
        species_selected = all_species
        update_panels()
        
    def species_selected(attrname, old, new):
        print(f"{now()} - species selected")
        nonlocal selected_species
        try:
            selected_species = [
                species_table.source.data['species'][idx] for idx in species_table.source.selected.indices
            ] or all_species
        except IndexError:
            selected_species = all_species
        status.text = f"Selected species {', '.join(selected_species)}"
        update_panels()
        
    def update_panels():
        station_filter = smr_observations['name_station'].isin(selected_stations)
        species_filter = smr_observations['species'].isin(selected_species)
        filtered_observations = smr_observations[station_filter & species_filter]
        print(f"{len(filtered_observations)} filtered observations")
        obs_table.source = obs_source(filtered_observations)
        species_table.source=species_source(filtered_observations)

    # There may be stations that have no observations, so we define this source independently of the observations
    station_source = ColumnDataSource(
        data=dict(
            lat=station_obs['lat'],
            lon=station_obs['lon'],
            name=station_obs['name'],
            count=station_obs['observations'],
            species=station_obs['species'],
            size=[10 + 7*math.log(v + 1) for v in station_obs['observations']],
        )
    )

    station_source.selected.on_change('indices', stations_selected)
        
    def obs_source(observations):
        column_source = ColumnDataSource(
            data=dict(
                obs_time=observations['start_time'],
                station=observations['name_station'],
                observer=observations['name_observer'],
                species=observations['species'],
                intensity=observations['call_intensity'],
                temperature=observations['temperature'],
                wind=observations['beaufort_wind'],
            )
        )
        column_source.selected.on_change('indices', obs_selected)
        return column_source

    def species_source(observations):
        by_species = observations.groupby('species')
        names = list(by_species.size().sort_values(ascending=False).keys())
        groups = dict(list(by_species))
        
        count, observers, sites = list(), list(), list()
        for species in names:
            group = groups[species]
            count.append(len(group))
            observers.append(len(group['name_observer'].unique()))
            sites.append(len(group['name_station'].unique()))
        column_source = ColumnDataSource(
            data=dict(
                species=names,
                observations=count,
                observers=observers,
                stations=sites
            )
        )
        column_source.selected.on_change('indices', species_selected)
        return column_source
    
    # Station map
    map_options = GMapOptions(lat=40.752, lng=-74.294, map_type="terrain", zoom=14)

    hover = HoverTool(tooltips=[
        ("site", "@name"),
    ])

    station_map = gmap(api_key, map_options,
                       tools=[hover, WheelZoomTool(), PanTool(), ResetTool(), TapTool()],
                       title="South Mountain Reservation")

    renderer = station_map.circle(x="lon", y="lat", size="size", 
                       fill_color="violet", fill_alpha=0.5,
                       hover_fill_alpha=1.0,
                       source=station_source)
    
    selected_circle = Circle(fill_alpha=1.0, fill_color="violet")
    nonselected_circle = Circle(fill_alpha=0.0, fill_color="violet")

    renderer.selection_glyph = selected_circle
    renderer.nonselection_glyph = nonselected_circle

    # Observations table
    obs_columns = [
        TableColumn(field="obs_time", title="Observed at", formatter=DateFormatter()),
        TableColumn(field="station", title="Station"),
        TableColumn(field="observer", title="Observer"),
        TableColumn(field="species", title="Species"),
        TableColumn(field="intensity", title="Intensity"),
    ]

    obs_table = DataTable(source=obs_source(smr_observations), columns=obs_columns, 
                          width=900, height=280, index_position=None, autosize_mode="fit_viewport")
    # Species table
    species_columns = [
        TableColumn(field="species", title="Species"),
        TableColumn(field="observations", title="Observed"),
        TableColumn(field="observers", title="Observers"),
        TableColumn(field="stations", title="Sites"),
    ]

    species_table = DataTable(source=species_source(smr_observations), columns=species_columns, 
                              width=900, height=280, margin=(30, 5, 5, 5), index_position=None,
                              autosize_mode="fit_viewport")
   
    status = Paragraph()
    
    def source_properties():
        lines = list()
        lines.append("obs_source:")
        for k, v in obs_source.properties_with_values().items():
            lines.append(f"{k:10s}: {str(v)[:64]}")
        lines.append("")
        lines.append("station_source:")
        for k, v in station_source.properties_with_values().items():
            lines.append(f"{k:10s}: {str(v)[:64]}")
        return "\n".join(lines)
    
    def selections():
        lines = list()
        lines.append(f"observations: {str(obs_table.source.selected.indices)}")
        lines.append(f"stations: {str(station_source.selected.indices)}")
        return "\t\t".join(lines)
    
    status.text = "all observations"
    print(status.text)

    doc.add_root(layout([[station_map, species_table], [status], [obs_table]]))
    
# In the notebook, just pass the function that defines the app to show
# You may need to supply notebook_url, e.g notebook_url="http://localhost:8889" 
show(update_display)
# Out:
# <script id="11921">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:40787/autoload.js?bokeh-autoload-element=11921&bokeh-absolute-url=http://localhost:40787&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# 7 stations
# 8 species
# all observations

# %% [markdown]
# #### WMTS Plots

# %%
from bokeh.plotting import figure
from bokeh.models import WMTSTileSource
from bokeh.tile_providers import get_provider, OSM

# %%
import math

def lonlat_to_web_mercator(lon=None, lat=None):
    """Converts lists of decimal longitude and latitude values to web mercator x and y values."""
    k = 6378137
    x = [v * (k * math.pi/180.0) for v in lon] if lon else []
    y = [math.log(math.tan((90.0 + v) * np.pi/360.0)) * k for v in lat] if lat else []
    return x, y

# %%
# web mercator coordinates
SMR = lonlat_to_web_mercator(lon=(-74.325, -74.270), lat=(40.775, 40.725))
x, y = lonlat_to_web_mercator(lon=list(station_obs["lon"]), lat=list(station_obs["lat"]))
station_obs["x"] = x
station_obs["y"] = y
SMR
# Out:
# ([-8273821.153210059, -8267698.581216428],
#  [4979210.647373081, 4971863.455919855])

# %%
source = ColumnDataSource(
    data = dict(
        lat=list(station_obs['lat']),
        lon=list(station_obs['lon']),
        x=list(station_obs['x']),
        y=list(station_obs['y']),
        name=list(station_obs['name']),
        count=list(station_obs['observations']),
        species=list(station_obs['species']),
        size=[10 + 7*math.log(v + 1) for v in station_obs['observations']],
    )
)

hover = HoverTool(tooltips=[
    ("site", "@name"),
    ("observations", "@count"),
    ("species", "@species")
])

p = figure(title="South Mountain Reservation",
           tools=[hover, WheelZoomTool(), PanTool(), ResetTool()], 
           x_range=SMR[0], y_range=SMR[1], 
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(get_provider(OSM))
# Out:
# TileRenderer(id='1127', ...)

# %%
p.circle(x="x", y="y", size="size", fill_color="violet", fill_alpha=0.8, source=source)
show(p)
# Out:
#   <div class="bk-root" id="6e83c81f-4380-4b9c-9a1e-e86f8f2d387e" data-root-id="1094"></div>
# 7 stations
# 8 species
# all observations
