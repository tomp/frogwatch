# %% [markdown]
# ## Frogwatch Observations

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Load data from DB

# %%
import psycopg2 as pg
db = pg.connect('postgresql://pollard@localhost:5432/frogwatch')

stations = pd.read_sql('select * from stations', db)
people = pd.read_sql('select * from persons', db)
observations = pd.read_sql('select * from observations', db)

# %%
# observations['fs_id'] = observations['fs_id'].apply(pd.to_numeric);
# stations['fs_id'] = stations['fs_id'].apply(pd.to_numeric);
# people['fs_id'] = people['fs_id'].apply(pd.to_numeric);

# %% [markdown]
# #### 1. Normalize species names

# %%
sorted(list(observations['species'].unique()))
# Out:
# ['-',
#  'African Clawed Frog',
#  'Amargosa Toad',
#  'American Bullfrog',
#  'American Toad',
#  'American Toad (Subspecies - Dwarf)',
#  'American Toad (Subspecies - Eastern)',
#  'Antillean Coqui',
#  'Arizona Toad',
#  'Arizona treefrog',
#  'Arroyo Toad',
#  'Atlantic Coast Leopard Frog',
#  'Baja California Treefrog',
#  'Barking Frog',
#  'Barking Treefrog',
#  'Bird-voiced Treefrog',
#  "Blanchard's Cricket Frog",
#  'Boreal Chorus Frog',
#  'Boreal/Western Chorus Frog Complex',
#  "Brimley's Chorus Frog",
#  'Cajun Chorus Frog',
#  'Cajun/Boreal Chorus Frog Complex',
#  'California Red-legged Frog',
#  'California Treefrog',
#  'Canadian Toad',
#  'Cane Toad',
#  'Canyon Treefrog',
#  'Carpenter Frog',
#  'Cliff Chirping Frog',
#  'Columbia Spotted Frog',
#  "Cope's Gray Treefrog",
#  'Coqui',
#  "Couch's Spadefoot",
#  'Crawfish Frog',
#  'Crawfish Frog (Subspecies - Northern)',
#  'Crawfish Frog (Subspecies - Southern)',
#  'Cricket Coqui',
#  'Cuban Treefrog',
#  'Eastern Cricket Frog',
#  'Eastern Narrow-mouthed Toad',
#  'Eastern Spadefoot',
#  'Florida Bog Frog',
#  'Florida Gopher Frog',
#  'Foothill Yellow-legged Frog',
#  "Fowler's Toad",
#  "Fowler's/Woodhouse's Toad Complex",
#  'Gopher Frog',
#  'Grass Coqui',
#  'Gray Treefrog',
#  'Great Basin Spadefoot',
#  'Great Plains Toad',
#  'Great Plains/Canadian Toad complex',
#  'Green Frog',
#  'Green Frog (Subspecies - Bronze)',
#  'Green Frog (Subspecies - Northern)',
#  'Green Toad',
#  'Green Toad (Subspecies - Eastern)',
#  'Green Treefrog',
#  'Greenhouse Frog',
#  'Gulf Coast Toad',
#  "Hurter's Spadefoot",
#  'Illinois Chorus Frog',
#  'Little Grass Frog',
#  'Lowland Leopard Frog',
#  'Mexican Spadefoot',
#  'Mink Frog',
#  'Mountain Chorus Frog',
#  'New Jersey Chorus Frog',
#  'No Species Heard',
#  'Northern Cricket Frog (Subspecies - Coastal)',
#  'Northern Cricket Frog Complex',
#  'Northern Leopard Frog',
#  'Northern Pacific Treefrog',
#  'Northern Red-legged Frog',
#  'Oak Toad',
#  'Ornate Chorus Frog',
#  'Pacific Treefrog Complex',
#  'Pickerel Frog',
#  'Pig Frog',
#  'Pine Barrens Treefrog',
#  'Pine Woods Treefrog',
#  'Plains Leopard Frog',
#  'Plains Spadefoot',
#  'Ramsey Canyon Leopard Frog',
#  'Red-legged Frog',
#  'Red-spotted toad',
#  'Rio Grande Chirping Frog',
#  'Rio Grande Leopard Frog',
#  'Sierran Treefrog',
#  'Sonoran Desert Toad',
#  'Southeastern/Western Chorus Frog Complex',
#  'Southern Chorus Frog',
#  'Southern Chorus Frog (Subspecies - Florida)',
#  'Southern Cricket Frog',
#  'Southern Cricket Frog (Subspecies - Coastal Plain)',
#  'Southern Cricket Frog (Subspecies - Florida)',
#  'Southern Leopard Frog',
#  'Southern Toad',
#  'Spotted Chorus Frog',
#  'Spring Peeper',
#  'Spring Peeper (Subspecies - Northern)',
#  'Spring Peeper (Subspecies - Southern)',
#  'Squirrel Treefrog',
#  "Strecker's Chorus frog",
#  'Tarahumara Frog',
#  'Texas Toad',
#  'Unknown Cricket Frog (Acris sp.)',
#  'Unknown Gray Treefrog Species Complex',
#  'Unknown Leopard Frog',
#  'Unknown Toad Species (Anaxyrus sp.)',
#  'Upland Chorus Frog',
#  'Warty Coqui',
#  'Web-footed Coqui',
#  'Western Chorus Frog',
#  'Western Narrow-mouthed Toad',
#  'Western Spadefoot',
#  'Western Toad',
#  'Western Toad (Subspecies - Boreal Toad)',
#  'Whistling Coqui',
#  'Wood Frog',
#  "Woodhouse's Toad",
#  "Woodhouse's Toad (Subspecies - Rocky Mountain Toad)",
#  "Woodhouse's Toad (Subspecies - Southwestern)"]

# %%
import re
observations['species'] = [re.sub(r" \(.*$", "", name) for name in observations['species']]

# %%
observations.groupby('species').size().sort_values(ascending=False).keys()
# Out:
# Index(['Spring Peeper', 'Green Frog', 'No Species Heard', 'Gray Treefrog',
#        'American Bullfrog', 'American Toad', 'Cope's Gray Treefrog',
#        'Wood Frog', 'Western Chorus Frog', 'Pickerel Frog',
#        ...
#        'Unknown Toad Species', 'Great Plains/Canadian Toad complex', 'Coqui',
#        'Ramsey Canyon Leopard Frog', 'Warty Coqui', 'Web-footed Coqui',
#        'Tarahumara Frog', 'Columbia Spotted Frog', 'Grass Coqui',
#        'Fowler's/Woodhouse's Toad Complex'],
#       dtype='object', name='species', length=108)

# %% [markdown]
# #### 2. Reassign duplicated SMR stations

# %%
stations[stations['name'].str.contains('SMR')]
# Out:
#           fs_id                                   name        lon        lat  \
# 131   100000202                    SMR-Campbell's Pond -74.305170  40.737490
# 139   100000215                    SMR-Campbell's Pond -74.303470  40.737706
# 141   100000217            SMR-Crest Trail Vernal Pool -74.290500  40.737440
# 142   100000218                  SMR-Black Willow Pond -74.292310  40.738760
# 143   100000219  SMR-Elmdale Peace Circle Vernal Pools -74.304090  40.746560
# 144   100000220       SMR-Oakdale Overflow Vernal Pool -74.288740  40.763240
# 4601  100000222             SMR-Orange Reservoir North -74.283385  40.768369
# 4602  100000221                  SMR-High Water Bypass -74.292300  40.752550
#
#               city        county state   owner_id
# 131        Milburn         Essex    NJ  100000108
# 139     Millburn\n  Essex County    NJ  100000204
# 141      Maplewood  Essex County    NJ  100000204
# 142      Maplewood  Essex County    NJ  100000204
# 143       Miilburn  Essex County    NJ  100000204
# 144    West Orange  Essex County    NJ  100000204
# 4601   West Orange  Essex County    NJ  100000204
# 4602  South Orange  Essex County    NJ  100000204

# %%
smr_station_ids = list([v for v in stations[stations['name'].str.contains('SMR')].fs_id])

# %%
len(observations[observations['station_id'].isin(smr_station_ids)])
# Out:
# 30

# %%
stations[stations['name'].str.contains('South Mountain')]
# Out:
#         fs_id                                               name        lon  \
# 454    593550  Crest Drive Deer exclosure, South Mountain Res... -74.292201
# 666    605236        Campbell's Pond, South Mountain Reservation -74.303005
# 1100  1480244  South Mountain Reservation Elmdale trail verna... -74.304660
# 6180  4975303    South Mountain Reservation-Elmdale/Peace Circle -74.297222
#
#             lat         city  county state owner_id
# 454   40.738704   Maplewood    Essex    NJ    20074
# 666   40.738104    Maplewood   Essex    NJ    20074
# 1100  40.747420     Millburn   Essex    NJ    20074
# 6180  40.746944  Short Hills  Essex     NJ    28679

# %%
observations.loc[observations['station_id'] == '593550', 'station_id'] = '100000218'
observations.loc[observations['station_id'] == '1480244', 'station_id'] = '100000219'
observations.loc[observations['station_id'] == '605236', 'station_id'] = '100000215'
observations.loc[observations['station_id'] == '100000202', 'station_id'] = '100000215'
smr_station_ids = [v for v in smr_station_ids if v != '100000202']

# %%
len(observations[observations['station_id'].isin(smr_station_ids)])
# Out:
# 70

# %% [markdown]
# ### Denormalize the obervations

# %%
obs_and_name = pd.merge(
         observations, 
         people[['fs_id', 'name']], 
         how="left", left_on="observer_id", right_on="fs_id", suffixes=[None, "_observer"])

# %%
obs_full = pd.merge(
         obs_and_name, 
         stations[['fs_id', 'name', 'lat', 'lon']], 
         how="left", left_on="station_id", right_on="fs_id", suffixes=["_observer", "_station"])

# %%
obs_full.columns
# Out:
# Index(['fs_id_observer', 'station_id', 'observer_id', 'start_time', 'end_time',
#        'species', 'call_intensity', 'temperature', 'beaufort_wind',
#        'precip_48h', 'precip', 'above_freezing_48h', 'notes', 'fs_id_observer',
#        'name_observer', 'fs_id_station', 'name_station', 'lat', 'lon'],
#       dtype='object')

# %%
observations = obs_full[['station_id', 'observer_id', 'start_time', 
                         'species', 'call_intensity', 'temperature', 'beaufort_wind', 
                         'name_observer', 'name_station', 'lat', 'lon']]

# %% [markdown]
# ### Convert start_time to a datetime

# %%
observations = observations.assign(
    start_time=pd.to_datetime(observations['start_time'], utc=True))
observations['start_time'].apply(lambda ts: ts.year)
# Out:
# 0         2021
# 1         2021
# 2         2021
# 3         2021
# 4         2021
#           ...
# 112340    2000
# 112341    2000
# 112342    2000
# 112343    2000
# 112344    2000
# Name: start_time, Length: 112345, dtype: int64

# %% [markdown]
# ### Extract South Mountain Reservation Observations

# %%
smr_observations = observations[observations['station_id'].isin(smr_station_ids) & 
                                (observations['start_time'].apply(lambda ts: ts.year) >= 2010)
                               ].sort_values(by=['start_time'], ascending=False)
smr_observations.loc[:, ('start_time', 'name_observer', 'species', 'call_intensity', 'temperature', 
                         'beaufort_wind', 'name_station')]
# Out:
#                      start_time      name_observer           species  \
# 1053  2021-05-13 20:33:00+00:00     Barbara Priest  No Species Heard
# 1051  2021-05-09 20:53:00+00:00        Nicky Lazar     Spring Peeper
# 1052  2021-05-01 20:36:00+00:00     Barbara Priest  No Species Heard
# 1040  2021-04-27 20:39:00+00:00   Cheryl Futterman  No Species Heard
# 1047  2021-04-19 20:38:00+00:00   Catherine Cronin     Spring Peeper
# ...                         ...                ...               ...
# 48940 2015-03-30 20:30:48+00:00  Henry Conrad-Poor     Spring Peeper
# 51113 2015-03-27 19:50:07+00:00  Henry Conrad-Poor     Spring Peeper
# 51114 2015-03-27 19:50:07+00:00  Henry Conrad-Poor         Wood Frog
# 51115 2015-03-21 20:00:02+00:00  Henry Conrad-Poor     Spring Peeper
# 51116 2015-03-21 20:00:02+00:00  Henry Conrad-Poor         Wood Frog
#
#       call_intensity  temperature beaufort_wind  \
# 1053               0         60.0             0
# 1051               1         50.0             0
# 1052               0         52.0             0
# 1040               0         56.0             0
# 1047               2         61.0             0
# ...              ...          ...           ...
# 48940              0         42.0             4
# 51113              2         45.0             0
# 51114              0         45.0             0
# 51115              0         40.0             3
# 51116              0         40.0             3
#
#                                 name_station
# 1053   SMR-Elmdale Peace Circle Vernal Pools
# 1051   SMR-Elmdale Peace Circle Vernal Pools
# 1052   SMR-Elmdale Peace Circle Vernal Pools
# 1040             SMR-Crest Trail Vernal Pool
# 1047                   SMR-Black Willow Pond
# ...                                      ...
# 48940                    SMR-Campbell's Pond
# 51113                  SMR-Black Willow Pond
# 51114                  SMR-Black Willow Pond
# 51115                  SMR-Black Willow Pond
# 51116                  SMR-Black Willow Pond
#
# [70 rows x 7 columns]

# %% [markdown]
# ### Create table of stations

# %%
from collections import defaultdict

station_obs = defaultdict(list)

# create an entry for every station in the given observations
for station_id, obs_ids in smr_observations.groupby(['station_id']).groups.items():
    obs = smr_observations.loc[obs_ids[0]]
    station_obs['station_id'].append(station_id)
    station_obs['name'].append(obs["name_station"])
    station_obs['lat'].append(obs['lat'])
    station_obs['lon'].append(obs["lon"])
    station_obs['observations'].append(len(obs_ids))

# Add stations that are defined, but have no observations
for station_id in smr_station_ids:
    if station_id not in station_obs['station_id']:
        station_obs['station_id'].append(station_id)
        station_obs['name'].append(stations.loc[stations['fs_id'] == station_id, "name"].iloc[0])
        station_obs['lat'].append(stations.loc[stations['fs_id'] == station_id, "lat"].iloc[0])
        station_obs['lon'].append(stations.loc[stations['fs_id'] == station_id, "lon"].iloc[0])
        station_obs['observations'].append(0)

station_obs = pd.DataFrame(station_obs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0912b01c1b41> in <module>
#      22
#      23 station_obs = pd.DataFrame(station_obs)
# ---> 24 station_obs['name'].get_loc('SMR-Orange Reservoir North')
#
# ~/metabase-stuff/FROG/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'get_loc'

# %%
#get_loc('SMR-Orange Reservoir North')
names = ['SMR-Orange Reservoir North', 'SMR-Black Willow Pond']
list(station_obs[station_obs['name'].isin(names)].index)
# Out:
# [2, 5]

# %% [markdown]
# ### Unified dashboard
#
# * Define sources for different the dashboard panels from the observations and a set of filters.
# * Allow filters to be defined by interacting with the panels.### Map the observations

# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool, PanTool, WheelZoomTool, ResetTool, TapTool
from bokeh.models import DataTable, DateFormatter, TableColumn
from bokeh.models import Circle, Paragraph
from bokeh.layouts import layout

# %%
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

# %%
from datetime import datetime
import math

def now():
    return datetime.now().isoformat()

def update_display(doc):

    # Set API key from environment in production:
    api_key = "AIzaSyD4IiUSTkgTTe800sjX5LIuVhUsAFsRqG4"

    all_stations = set(station_obs['name'])
    selected_stations = all_stations
    print(f"{len(selected_stations)} stations")

    all_species = set(smr_observations['species'])
    selected_species = all_species
    print(f"{len(selected_species)} species")

    all_observers = set(smr_observations['name_observer'])
    selected_observers = all_observers
    print(f"{len(selected_observers)} observers")
    
    def something_changed(attrname, old, new):
        print(attrname + " " + repr(old))

    def obs_selected(attrname, old, new):
        print(f"{now()} - observation selected")
        # status.text = f"observations {obs_table.source.selected.indices} selected"
        
    def stations_selected(attrname, old, new):
        print(f"{now()} - station selected")
        nonlocal selected_stations
        selected_stations = list(station_obs['name'][station_source.selected.indices]) or all_stations
        print(f"Selected stations {', '.join(selected_stations)}")
        species_selected = all_species
        update_panels()
        
    def species_selected(attrname, old, new):
        print(f"{now()} - species selected")
        nonlocal selected_species
        try:
            selected_species = [
                species_table.source.data['species'][idx] for idx in species_table.source.selected.indices
            ] or all_species
        except IndexError:
            selected_species = all_species
        # status.text = f"Selected species {', '.join(selected_species)}"
        update_panels()
        
    def observer_selected(attrname, old, new):
        print(f"{now()} - observer selected")
        nonlocal selected_observers
        try:
            selected_observers = [
                people_table.source.data['name_observer'][idx] for idx in people_table.source.selected.indices
            ] or all_observers
        except IndexError:
            selected_observers = all_observers
        # status.text = f"Selected observers {', '.join(selected_observers)}"
        update_panels()
        
    def update_panels():
        nonlocal selected_stations
        station_filter = smr_observations['name_station'].isin(selected_stations)
        species_filter = smr_observations['species'].isin(selected_species)
        observer_filter = smr_observations['name_observer'].isin(selected_observers)
        filtered_observations = smr_observations[
            station_filter & species_filter & observer_filter
        ]
        print(f"{len(filtered_observations)} filtered observations")
        
        if len(filtered_observations) == len(smr_observations):
            selected_stations = all_stations
            station_source.selected.indices = []
        elif len(selected_stations) == len(all_stations):
            stations = filtered_observations['name_station'].unique()
            station_source.selected.indices = list(station_obs[station_obs['name'].isin(stations)].index)
            print(f"set station indices to {station_source.selected.indices}")

        obs_table.source = obs_source(filtered_observations)
        species_table.source=species_source(filtered_observations)
        people_table.source=people_source(filtered_observations)

    # There may be stations that have no observations, so we define this source independently of the observations
    station_source = ColumnDataSource(
        data=dict(
            lat=station_obs['lat'],
            lon=station_obs['lon'],
            name=station_obs['name'],
            count=station_obs['observations'],
            size=[15 + 5*math.log(v + 1) for v in station_obs['observations']],
        )
    )

    station_source.selected.on_change('indices', stations_selected)
        
    def obs_source(observations):
        column_source = ColumnDataSource(
            data=dict(
                obs_time=observations['start_time'],
                station=observations['name_station'],
                observer=observations['name_observer'],
                species=observations['species'],
                intensity=observations['call_intensity'],
                temperature=observations['temperature'],
                wind=observations['beaufort_wind'],
            )
        )
        column_source.selected.on_change('indices', obs_selected)
        return column_source

    def species_source(observations):
        by_species = observations.groupby('species')
        names = list(by_species.size().sort_values(ascending=False).keys())
        groups = dict(list(by_species))
        
        count, observers, sites = list(), list(), list()
        for species in names:
            group = groups[species]
            count.append(len(group))
            observers.append(len(group['name_observer'].unique()))
            sites.append(len(group['name_station'].unique()))
        column_source = ColumnDataSource(
            data=dict(
                species=names,
                observations=count,
                observers=observers,
                stations=sites
            )
        )
        column_source.selected.on_change('indices', species_selected)
        return column_source

    def unique_species(species_list):
        """Return a list of the unique species in the given list."""
        species = set([v for v in species_list if v != "No Species Heard"])
        return sorted(list(species))
        
    def people_source(observations):
        by_observer = observations.groupby('name_observer')
        names = list(by_observer.size().sort_values(ascending=False).keys())
        groups = dict(list(by_observer))
        
        count, species, sites = list(), list(), list()
        for observer in names:
            group = groups[observer]
            count.append(len(group))
            species.append(len(unique_species(group['species'])))
            sites.append(len(group['name_station'].unique()))
        column_source = ColumnDataSource(
            data=dict(
                name_observer=names,
                observations=count,
                species=species,
                stations=sites
            )
        )
        column_source.selected.on_change('indices', observer_selected)
        return column_source
    
    # Station map
    map_options = GMapOptions(lat=40.752, lng=-74.294, map_type="terrain", zoom=14)

    hover = HoverTool(tooltips=[
        ("site", "@name"),
    ])

    station_map = gmap(api_key, map_options,
                       tools=[hover, WheelZoomTool(), PanTool(), ResetTool(), TapTool()],
                       width=400,
                       title="South Mountain Reservation")

    renderer = station_map.circle(x="lon", y="lat", size="size", 
                       fill_color="violet", fill_alpha=0.5,
                       hover_fill_alpha=1.0,
                       source=station_source)
    
    selected_circle = Circle(fill_alpha=1.0, fill_color="violet")
    nonselected_circle = Circle(fill_alpha=0.0, fill_color="violet")

    renderer.selection_glyph = selected_circle
    renderer.nonselection_glyph = nonselected_circle

    # Observations tablesource
    obs_columns = [
        TableColumn(field="obs_time", title="Observed at", formatter=DateFormatter()),
        TableColumn(field="station", title="Station"),
        TableColumn(field="observer", title="Observer"),
        TableColumn(field="species", title="Species"),
        TableColumn(field="intensity", title="Intensity"),
    ]

    obs_table = DataTable(source=obs_source(smr_observations), columns=obs_columns, 
                          width=810, height=320, index_position=None)
    # Species table
    species_columns = [
        TableColumn(field="species", title="Species"),
        TableColumn(field="observations", title="Observed"),
        TableColumn(field="observers", title="Observers"),
        TableColumn(field="stations", title="Sites"),
    ]

    species_table = DataTable(source=species_source(smr_observations), 
                              columns=species_columns, 
                              width=400, height=240, margin=(30, 5, 5, 5), 
                              index_position=None)
    # Observers table
    people_columns = [
        TableColumn(field="name_observer", title="Observer"),
        TableColumn(field="observations", title="Observed"),
        TableColumn(field="species", title="Species"),
        TableColumn(field="stations", title="Sites"),
    ]

    people_table = DataTable(source=people_source(smr_observations), 
                              columns=people_columns, 
                              width=400, height=320, margin=(30, 5, 5, 5), 
                              index_position=None)
    
    status = Paragraph()
    
    def source_properties():
        lines = list()
        lines.append("obs_source:")
        for k, v in obs_source.properties_with_values().items():
            lines.append(f"{k:10s}: {str(v)[:64]}")
        lines.append("")
        lines.append("station_source:")
        for k, v in station_source.properties_with_values().items():
            lines.append(f"{k:10s}: {str(v)[:64]}")
        return "\n".join(lines)
    
    def selections():
        lines = list()
        lines.append(f"observations: {str(obs_table.source.selected.indices)}")
        lines.append(f"stations: {str(station_source.selected.indices)}")
        return "\t\t".join(lines)
    
    # status.text = "all observations"
    # print(status.text)

    doc.add_root(layout(
        [[station_map, [species_table, people_table]], [obs_table]])
    )
    
# In the notebook, just pass the function that defines the app to show
# You may need to supply notebook_url, e.g notebook_url="http://localhost:8889" 
show(update_display)
# Out:
# <script id="13405">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:36075/autoload.js?bokeh-autoload-element=13405&bokeh-absolute-url=http://localhost:36075&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# 7 stations
# 8 species
# 10 observers
# 2021-05-19T15:28:14.221012 - station selected
# Selected stations SMR-Campbell's Pond
# 23 filtered observations
# 2021-05-19T15:28:30.324612 - station selected
# Selected stations SMR-Elmdale Peace Circle Vernal Pools, SMR-Orange Reservoir North, SMR-Crest Trail Vernal Pool, SMR-Oakdale Overflow Vernal Pool, SMR-Campbell's Pond, SMR-High Water Bypass, SMR-Black Willow Pond
# 70 filtered observations
